# %%
from chunker import train_classifier
from word_count import tokenize
cl = train_classifier()

# %%
text = "Hey guys, I just thought I'd share with you my experience with WellbutrinXL 24 hour 150mg antidepressants and ask your opinions on this drug.Just the other night I was here posting about how shitty I felt and how thoughts of suicide kept creeping into my mind. Recently I started taking Wellbutrin in the morning, and holy shit. I haven't felt this good in a really long time. Things dont bother me nearly as much, and I'm 100X more productive. I dont have trouble getting out of bed in the morning anymore and I'm actually eager to go about my day, a feeling I haven't had in months.  I don't even really know why I'm posting this, I guess I'm just so psyched about this that I wanted to share it with you guys. Does anyone here take Wellbutrin or previously taken it? I feel great, but I'm slightly worried about the long list of side effects. Thoughts?"

# %%
text
# Out:
# "Hey guys, I just thought I'd share with you my experience with WellbutrinXL 24 hour 150mg antidepressants and ask your opinions on this drug.Just the other night I was here posting about how shitty I felt and how thoughts of suicide kept creeping into my mind. Recently I started taking Wellbutrin in the morning, and holy shit. I haven't felt this good in a really long time. Things dont bother me nearly as much, and I'm 100X more productive. I dont have trouble getting out of bed in the morning anymore and I'm actually eager to go about my day, a feeling I haven't had in months.  I don't even really know why I'm posting this, I guess I'm just so psyched about this that I wanted to share it with you guys. Does anyone here take Wellbutrin or previously taken it? I feel great, but I'm slightly worried about the long list of side effects. Thoughts?"

# %%
tokens = tokenize(text,'wellbutrin',False,True)

# %%
tokens
# Out:
# ['hey',
#  u'guy',
#  u'think',
#  'd',
#  'share',
#  'experience',
#  'wellbutrinxl',
#  '24',
#  'hour',
#  '150mg',
#  'ask',
#  u'opinion',
#  'night',
#  u'post',
#  'shitty',
#  'felt',
#  u'thought',
#  'suicide',
#  u'keep',
#  u'creep',
#  'mind',
#  'recently',
#  'morning',
#  'holy',
#  'shit',
#  'haven',
#  'felt',
#  'good',
#  'long',
#  'time',
#  'dont',
#  'bother',
#  'nearly',
#  '100x',
#  'productive',
#  'dont',
#  'trouble',
#  'bed',
#  'morning',
#  'anymore',
#  'actually',
#  'eager',
#  'go',
#  'day',
#  u'feel',
#  'haven',
#  u'month',
#  'even',
#  'know',
#  u'post',
#  'guess',
#  'psyched',
#  u'want',
#  'share',
#  u'guy',
#  'anyone',
#  'previously',
#  'feel',
#  'great',
#  'slightly',
#  u'worry',
#  'long',
#  'list',
#  u'side_effect',
#  u'thought']

# %%
cl.classify(dict([(word,True) for word in tokens]))
# Out:
# 'neg'

# %%
cl.prob_classify(dict([(word,True) for word in tokens])).prob('pos')
# Out:
# 0.4061024992671394

# %%
res = cl.prob_classify(dict([(word,True) for word in tokens]))

# %%
res.prob('pos')
# Out:
# 0.4061024992671394

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer

# %%
t=PunktSentenceTokenizer()

# %%
t.tokenize(text)
# Out:
# ["Hey guys, I just thought I'd share with you my experience with WellbutrinXL 24 hour 150mg antidepressants and ask your opinions on this drug.Just the other night I was here posting about how shitty I felt and how thoughts of suicide kept creeping into my mind.",
#  'Recently I started taking Wellbutrin in the morning, and holy shit.',
#  "I haven't felt this good in a really long time.",
#  "Things dont bother me nearly as much, and I'm 100X more productive.",
#  "I dont have trouble getting out of bed in the morning anymore and I'm actually eager to go about my day, a feeling I haven't had in months.",
#  "I don't even really know why I'm posting this, I guess I'm just so psyched about this that I wanted to share it with you guys.",
#  'Does anyone here take Wellbutrin or previously taken it?',
#  "I feel great, but I'm slightly worried about the long list of side effects.",
#  'Thoughts?']

# %%
sents = []
for s in t.tokenize(text):
    sent = cl.prob_classify(dict([(word,True) for word in tokenize(s)])).prob('pos')
    sents.append(sent)

# %%
import numpy

# %%
sents = numpy.array(sents)

# %%
numpy.mean(sents)
# Out:
# 0.50960440010246855

# %% [markdown]
# # recommender

# %%
import pandas
import pymysql as pms

# %%
conn = pms.connect(host='localhost',
		user='root',
		passwd='',
		db='empath',
		charset='utf8',
		init_command='SET NAMES UTF8')
cur = conn.cursor()

# %%
drug = 'citalopram'

# %%
query = ("SELECT c.id,c.sents,c.nbsent from Chunks c "
		"JOIN Mentions m on c.id=m.id "
		"WHERE (m.count=2 AND c.drug='%s' AND c.precedence=1)" % drug.lower())

# %%
data = pandas.read_sql(query,conn)

# %%
data.head(20)
# Out:
#          id              sents    nbsent
# 0   cnaxpxy          Negative   0.431251
# 1   cnaz58k          Negative   0.624999
# 2   cnc21da          Negative   0.723175
# 3   cndtodr  Neutral Negative   0.995276
# 4   cndz93a          Negative   0.624999
# 5   cnblb7s  Negative Neutral   0.322200
# 6   cnc164y  Negative Neutral   0.822429
# 7   cnd33st          Negative   0.506486
# 8   cndsgf2          Negative   0.785233
# 9   cnemxpo          Negative   0.734260
# 10  cnews7p          Negative   0.637081
# 11  cnfygu0  Negative Neutral   0.131858
# 12  cnip42q          Negative   0.624999
# 13  cniisl9          Negative   0.624999
# 14  cniiy5h          Negative   0.624999
# 15  cnkyh9l  Negative Neutral   0.999551
# 16  cnlyarz          Negative   0.875778
# 17  cvo5mh7          Negative   0.760831
# 18  cnj9vhu          Negative   0.797726
# 19  cnjpuhe          Positive   0.624999

# %%
for id in data.id:
    print id
# Out:
# cnaxpxy
# cnaz58k
# cnc21da
# cndtodr
# cndz93a
# cnblb7s
# cnc164y
# cnd33st
# cndsgf2
# cnemxpo
# cnews7p
# cnfygu0
# cnip42q
# cniisl9
# cniiy5h
# cnkyh9l
# cnlyarz
# cvo5mh7
# cnj9vhu
# cnjpuhe
# cnhe0ea
# cnkt8hl
# cnnpopy
# cno4vtp
# cnoa5wy
# cnpf6x2
# cnpg166
# cnqnt9w
# cnx4zv8
# cnxfogl
# cny62qb
# co73hhe
# cny256z
# co3n58h

# %%
finishes = {}
for post_id in data.id:
	print post_id
	query = ("SELECT c.id,c.drug,c.sents,c.nbsent from Chunks c "
		"WHERE (c.precedence=2 and c.id='%s')" % post_id)
	cur.execute(query)
	for row in cur:
		finishes[post_id] = (row[1],row[2],row[3])
# Out:
# cnaxpxy
# cnaz58k
# cnc21da
# cndtodr
# cndz93a
# cnblb7s
# cnc164y
# cnd33st
# cndsgf2
# cnemxpo
# cnews7p
# cnfygu0
# cnip42q
# cniisl9
# cniiy5h
# cnkyh9l
# cnlyarz
# cvo5mh7
# cnj9vhu
# cnjpuhe
# cnhe0ea
# cnkt8hl
# cnnpopy
# cno4vtp
# cnoa5wy
# cnpf6x2
# cnpg166
# cnqnt9w
# cnx4zv8
# cnxfogl
# cny62qb
# co73hhe
# cny256z
# co3n58h

# %%
finishes
# Out:
# {u'cnaxpxy': (u'escitalopram', u'Negative ', 0.0932147),
#  u'cnaz58k': (u'escitalopram', u'Negative ', 0.000971083),
#  u'cnblb7s': (u'fluoxetine', u'Negative ', 0.193752),
#  u'cnc164y': (u'sertraline', u'Negative ', 0.441225),
#  u'cnc21da': (u'bupropion', u'Negative ', 0.996929),
#  u'cnd33st': (u'venlafaxine', u'Negative ', 0.843677),
#  u'cndsgf2': (u'venlafaxine', u'Positive ', 0.997087),
#  u'cndtodr': (u'bupropion', u'Negative ', 0.999931),
#  u'cndz93a': (u'bupropion', u'Negative ', 0.968423),
#  u'cnemxpo': (u'venlafaxine', u'Negative ', 0.999898),
#  u'cnews7p': (u'escitalopram', u'Negative ', 0.000145229),
#  u'cnfygu0': (u'fluoxetine', u'Negative ', 0.503621),
#  u'cnhe0ea': (u'fluoxetine', u'Negative ', 0.956195),
#  u'cniisl9': (u'escitalopram', u'Negative ', 0.380914),
#  u'cniiy5h': (u'escitalopram', u'Negative ', 0.125),
#  u'cnip42q': (u'duloxetine', u'Negative ', 0.991882),
#  u'cnj9vhu': (u'bupropion', u'Negative ', 0.998475),
#  u'cnjpuhe': (u'bupropion', u'Positive ', 0.897571),
#  u'cnkt8hl': (u'sertraline', u'Negative ', 0.734431),
#  u'cnkyh9l': (u'escitalopram', u'Negative ', 0.125),
#  u'cnlyarz': (u'mirtazapine', u'Negative ', 0.256903),
#  u'cnnpopy': (u'escitalopram', u'Negative Positive Negative ', 0.981467),
#  u'cno4vtp': (u'bupropion', u'Negative ', 0.673559),
#  u'cnoa5wy': (u'escitalopram', u'Negative ', 0.0121117),
#  u'cnpf6x2': (u'fluoxetine', u'Negative ', 0.503326),
#  u'cnpg166': (u'escitalopram', u'Negative ', 0.968142),
#  u'cnqnt9w': (u'escitalopram', u'Negative ', 0.998016),
#  u'cnx4zv8': (u'escitalopram', u'Negative ', 0.125),
#  u'cnxfogl': (u'escitalopram', u'Negative ', 0.127865),
#  u'cny256z': (u'paroxetine', u'Negative ', 0.581239),
#  u'cny62qb': (u'escitalopram', u'Negative ', 0.0552622),
#  u'co3n58h': (u'paroxetine', u'Negative ', 0.279217),
#  u'co73hhe': (u'mirtazapine', u'Negative ', 0.893259),
#  u'cvo5mh7': (u'olanzapine', u'Negative ', 0.956407)}

# %%
finishes = pandas.DataFrame.from_dict(finishes,orient='index')
finishes.columns = ['drug','sent','nbsent']

# %%
finishes.head(50)
# Out:
#                  drug                         sent    nbsent
# cnoa5wy  escitalopram                    Negative   0.012112
# cnxfogl  escitalopram                    Negative   0.127865
# cniiy5h  escitalopram                    Negative   0.125000
# cnpg166  escitalopram                    Negative   0.968142
# cnlyarz   mirtazapine                    Negative   0.256903
# cvo5mh7    olanzapine                    Negative   0.956407
# cnj9vhu     bupropion                    Negative   0.998475
# cnnpopy  escitalopram  Negative Positive Negative   0.981467
# cny256z    paroxetine                    Negative   0.581239
# cnkt8hl    sertraline                    Negative   0.734431
# cndz93a     bupropion                    Negative   0.968423
# cnaxpxy  escitalopram                    Negative   0.093215
# cniisl9  escitalopram                    Negative   0.380914
# cnemxpo   venlafaxine                    Negative   0.999898
# cnhe0ea    fluoxetine                    Negative   0.956195
# co3n58h    paroxetine                    Negative   0.279217
# cnpf6x2    fluoxetine                    Negative   0.503326
# cndtodr     bupropion                    Negative   0.999931
# cnx4zv8  escitalopram                    Negative   0.125000
# cnip42q    duloxetine                    Negative   0.991882
# cnc21da     bupropion                    Negative   0.996929
# cnfygu0    fluoxetine                    Negative   0.503621
# cnews7p  escitalopram                    Negative   0.000145
# cnblb7s    fluoxetine                    Negative   0.193752
# cno4vtp     bupropion                    Negative   0.673559
# cnkyh9l  escitalopram                    Negative   0.125000
# cnaz58k  escitalopram                    Negative   0.000971
# cndsgf2   venlafaxine                    Positive   0.997087
# cnd33st   venlafaxine                    Negative   0.843677
# cny62qb  escitalopram                    Negative   0.055262
# cnc164y    sertraline                    Negative   0.441225
# co73hhe   mirtazapine                    Negative   0.893259
# cnjpuhe     bupropion                    Positive   0.897571
# cnqnt9w  escitalopram                    Negative   0.998016

# %% [markdown]
# ok let's reup this and check the outputs so far.

# %%
reload(rec)
starts,finishes = rec.recommend('escitalopram')

# %%
starts.head(10)
# Out:
#         id                      sents        nbsent
# 0  cnds3q2                   Neutral   1.250000e-01
# 1  cnj5fqc  Neutral Negative Neutral   4.473050e-08
# 2  cnmoqai                  Negative   1.250000e-01
# 3  cntsj5z                  Negative   1.250000e-01
# 4  cnytn48                   Neutral   1.250000e-01

# %%
finishes.head(10)
# Out:
#                drug                       sents    nbsent
# cnytn48  citalopram                    Neutral   0.545309
# cnmoqai  citalopram                   Negative   0.683834
# cntsj5z  citalopram                   Negative   0.027155
# cnds3q2  citalopram                    Neutral   0.079803
# cnj5fqc  citalopram  Neutral Negative Positive   0.191323

# %% [markdown]
# so that's coming out right.

# %%
conn.close()

# %%
reload(rec)
sod,starts,finishes = rec.recommend('citalopram')

# %%
sod
# Out:
# 131

# %%
starts
# Out:
#          id               sents    nbsent
# 0   cnaxpxy           Negative   0.431251
# 1   cnaz58k           Negative   0.624999
# 2   cnc21da           Negative   0.723175
# 3   cndtodr   Neutral Negative   0.995276
# 4   cndz93a           Negative   0.624999
# 5   cnblb7s   Negative Neutral   0.322200
# 6   cnc164y   Negative Neutral   0.822429
# 7   cnd33st           Negative   0.506486
# 8   cndsgf2           Negative   0.785233
# 9   cnemxpo           Negative   0.734260
# 10  cnews7p           Negative   0.637081
# 11  cnfygu0   Negative Neutral   0.131858
# 12  cnip42q           Negative   0.624999
# 13  cniisl9           Negative   0.624999
# 14  cniiy5h           Negative   0.624999
# 15  cnkyh9l   Negative Neutral   0.999551
# 16  cnlyarz           Negative   0.875778
# 17  cvo5mh7           Negative   0.760831
# 18  cnj9vhu           Negative   0.797726
# 19  cnjpuhe           Positive   0.624999
# 20  cnhe0ea            Neutral   0.572767
# 21  cnkt8hl           Negative   0.652007
# 22  cnnpopy           Negative   0.762920
# 23  cno4vtp           Negative   0.614881
# 24  cnoa5wy  Negative Negative   0.999235
# 25  cnpf6x2           Negative   0.624999
# 26  cnpg166           Negative   0.624999
# 27  cnqnt9w           Negative   0.526254
# 28  cnx4zv8           Negative   0.620908
# 29  cnxfogl           Negative   0.624999
# 30  cny62qb           Negative   0.740313
# 31  co73hhe            Neutral   0.745559
# 32  cny256z            Neutral   0.511831
# 33  co3n58h           Negative   0.442169
# 34  cxg1fcg           Negative   0.624999

# %%
finishes
# Out:
#                   drug                        sents    nbsent
# cxg1fcg  amitriptyline                    Negative   0.995185
# cnoa5wy   escitalopram                    Negative   0.012112
# cnxfogl   escitalopram                    Negative   0.127865
# cniiy5h   escitalopram                    Negative   0.125000
# cnpg166   escitalopram                    Negative   0.968142
# cnlyarz    mirtazapine                    Negative   0.256903
# cvo5mh7     olanzapine                    Negative   0.956407
# cnj9vhu      bupropion                    Negative   0.998475
# cnnpopy   escitalopram  Negative Positive Negative   0.981467
# cny256z     paroxetine                    Negative   0.581239
# cnkt8hl     sertraline                    Negative   0.734431
# cndz93a      bupropion                    Negative   0.968423
# cnaxpxy   escitalopram                    Negative   0.093215
# cniisl9   escitalopram                    Negative   0.380914
# cnemxpo    venlafaxine                    Negative   0.999898
# cnhe0ea     fluoxetine                    Negative   0.956195
# co3n58h     paroxetine                    Negative   0.279217
# cnpf6x2     fluoxetine                    Negative   0.503326
# cndtodr      bupropion                    Negative   0.999931
# cnx4zv8   escitalopram                    Negative   0.125000
# cnip42q     duloxetine                    Negative   0.991882
# cnc21da      bupropion                    Negative   0.996929
# cnfygu0     fluoxetine                    Negative   0.503621
# cnews7p   escitalopram                    Negative   0.000145
# cnblb7s     fluoxetine                    Negative   0.193752
# cno4vtp      bupropion                    Negative   0.673559
# cnkyh9l   escitalopram                    Negative   0.125000
# cnaz58k   escitalopram                    Negative   0.000971
# cndsgf2    venlafaxine                    Positive   0.997087
# cnd33st    venlafaxine                    Negative   0.843677
# cny62qb   escitalopram                    Negative   0.055262
# cnc164y     sertraline                    Negative   0.441225
# co73hhe    mirtazapine                    Negative   0.893259
# cnjpuhe      bupropion                    Positive   0.897571
# cnqnt9w   escitalopram                    Negative   0.998016

# %% [markdown]
# So we can get a rough statistic for how many people stayed on the drug vs. switched from it, and to what.  Now to filter and find the most common drug (maybe taking the most common one with better sentiment?)

# %%
finishes[finishes.nbsent > .5]
# Out:
#                   drug                        sents    nbsent
# cxg1fcg  amitriptyline                    Negative   0.995185
# cnpg166   escitalopram                    Negative   0.968142
# cvo5mh7     olanzapine                    Negative   0.956407
# cnj9vhu      bupropion                    Negative   0.998475
# cnnpopy   escitalopram  Negative Positive Negative   0.981467
# cny256z     paroxetine                    Negative   0.581239
# cnkt8hl     sertraline                    Negative   0.734431
# cndz93a      bupropion                    Negative   0.968423
# cnemxpo    venlafaxine                    Negative   0.999898
# cnhe0ea     fluoxetine                    Negative   0.956195
# cnpf6x2     fluoxetine                    Negative   0.503326
# cndtodr      bupropion                    Negative   0.999931
# cnip42q     duloxetine                    Negative   0.991882
# cnc21da      bupropion                    Negative   0.996929
# cnfygu0     fluoxetine                    Negative   0.503621
# cno4vtp      bupropion                    Negative   0.673559
# cndsgf2    venlafaxine                    Positive   0.997087
# cnd33st    venlafaxine                    Negative   0.843677
# co73hhe    mirtazapine                    Negative   0.893259
# cnjpuhe      bupropion                    Positive   0.897571
# cnqnt9w   escitalopram                    Negative   0.998016

# %%
starts[starts.id=='cnqnt9w'].nbsent.values
# Out:
# array([ 0.526254])

# %%
finishes[finishes.nbsent > starts[starts.id==finishes.index].nbsent.values[0]]
# Out:
#                   drug                        sents    nbsent
# cxg1fcg  amitriptyline                    Negative   0.995185
# cnpg166   escitalopram                    Negative   0.968142
# cvo5mh7     olanzapine                    Negative   0.956407
# cnj9vhu      bupropion                    Negative   0.998475
# cnnpopy   escitalopram  Negative Positive Negative   0.981467
# cnkt8hl     sertraline                    Negative   0.734431
# cndz93a      bupropion                    Negative   0.968423
# cnemxpo    venlafaxine                    Negative   0.999898
# cnhe0ea     fluoxetine                    Negative   0.956195
# cndtodr      bupropion                    Negative   0.999931
# cnip42q     duloxetine                    Negative   0.991882
# cnc21da      bupropion                    Negative   0.996929
# cno4vtp      bupropion                    Negative   0.673559
# cndsgf2    venlafaxine                    Positive   0.997087
# cnd33st    venlafaxine                    Negative   0.843677
# co73hhe    mirtazapine                    Negative   0.893259
# cnjpuhe      bupropion                    Positive   0.897571
# cnqnt9w   escitalopram                    Negative   0.998016

# %%
starts.id==finishes.index
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# Name: id, dtype: bool

# %%
reload(rec)
sod,data = rec.recommend('citalopram')

# %%
data
# Out:
#                   init_sent  init_nbsent           drug  \
# cxg1fcg           Negative      0.624999  amitriptyline
# cnoa5wy  Negative Negative      0.999235   escitalopram
# cniiy5h           Negative      0.624999   escitalopram
# cnhe0ea            Neutral      0.572767     fluoxetine
# cnpg166           Negative      0.624999   escitalopram
# cnlyarz           Negative      0.875778    mirtazapine
# cvo5mh7           Negative      0.760831     olanzapine
# cnj9vhu           Negative      0.797726      bupropion
# cnxfogl           Negative      0.624999   escitalopram
# cny256z            Neutral      0.511831     paroxetine
# cnkt8hl           Negative      0.652007     sertraline
# cndz93a           Negative      0.624999      bupropion
# cnaxpxy           Negative      0.431251   escitalopram
# cniisl9           Negative      0.624999   escitalopram
# cnemxpo           Negative      0.734260    venlafaxine
# cnnpopy           Negative      0.762920   escitalopram
# co3n58h           Negative      0.442169     paroxetine
# cnpf6x2           Negative      0.624999     fluoxetine
# cndtodr   Neutral Negative      0.995276      bupropion
# cnx4zv8           Negative      0.620908   escitalopram
# cnjpuhe           Positive      0.624999      bupropion
# cnc21da           Negative      0.723175      bupropion
# cnfygu0   Negative Neutral      0.131858     fluoxetine
# cnews7p           Negative      0.637081   escitalopram
# cnblb7s   Negative Neutral      0.322200     fluoxetine
# cno4vtp           Negative      0.614881      bupropion
# cnkyh9l   Negative Neutral      0.999551   escitalopram
# cnaz58k           Negative      0.624999   escitalopram
# cndsgf2           Negative      0.785233    venlafaxine
# cnd33st           Negative      0.506486    venlafaxine
# cny62qb           Negative      0.740313   escitalopram
# cnc164y   Negative Neutral      0.822429     sertraline
# co73hhe            Neutral      0.745559    mirtazapine
# cnip42q           Negative      0.624999     duloxetine
# cnqnt9w           Negative      0.526254   escitalopram
#
#                           final_sent  final_nbsent
# cxg1fcg                    Negative       0.995185
# cnoa5wy                    Negative       0.012112
# cniiy5h                    Negative       0.125000
# cnhe0ea                    Negative       0.956195
# cnpg166                    Negative       0.968142
# cnlyarz                    Negative       0.256903
# cvo5mh7                    Negative       0.956407
# cnj9vhu                    Negative       0.998475
# cnxfogl                    Negative       0.127865
# cny256z                    Negative       0.581239
# cnkt8hl                    Negative       0.734431
# cndz93a                    Negative       0.968423
# cnaxpxy                    Negative       0.093215
# cniisl9                    Negative       0.380914
# cnemxpo                    Negative       0.999898
# cnnpopy  Negative Positive Negative       0.981467
# co3n58h                    Negative       0.279217
# cnpf6x2                    Negative       0.503326
# cndtodr                    Negative       0.999931
# cnx4zv8                    Negative       0.125000
# cnjpuhe                    Positive       0.897571
# cnc21da                    Negative       0.996929
# cnfygu0                    Negative       0.503621
# cnews7p                    Negative       0.000145
# cnblb7s                    Negative       0.193752
# cno4vtp                    Negative       0.673559
# cnkyh9l                    Negative       0.125000
# cnaz58k                    Negative       0.000971
# cndsgf2                    Positive       0.997087
# cnd33st                    Negative       0.843677
# cny62qb                    Negative       0.055262
# cnc164y                    Negative       0.441225
# co73hhe                    Negative       0.893259
# cnip42q                    Negative       0.991882
# cnqnt9w                    Negative       0.998016

# %%
data[data.init_nbsent < data.final_nbsent]
# Out:
#                  init_sent  init_nbsent           drug  \
# cxg1fcg          Negative      0.624999  amitriptyline
# cnhe0ea           Neutral      0.572767     fluoxetine
# cnpg166          Negative      0.624999   escitalopram
# cvo5mh7          Negative      0.760831     olanzapine
# cnj9vhu          Negative      0.797726      bupropion
# cny256z           Neutral      0.511831     paroxetine
# cnkt8hl          Negative      0.652007     sertraline
# cndz93a          Negative      0.624999      bupropion
# cnemxpo          Negative      0.734260    venlafaxine
# cnnpopy          Negative      0.762920   escitalopram
# cndtodr  Neutral Negative      0.995276      bupropion
# cnjpuhe          Positive      0.624999      bupropion
# cnc21da          Negative      0.723175      bupropion
# cnfygu0  Negative Neutral      0.131858     fluoxetine
# cno4vtp          Negative      0.614881      bupropion
# cndsgf2          Negative      0.785233    venlafaxine
# cnd33st          Negative      0.506486    venlafaxine
# co73hhe           Neutral      0.745559    mirtazapine
# cnip42q          Negative      0.624999     duloxetine
# cnqnt9w          Negative      0.526254   escitalopram
#
#                           final_sent  final_nbsent
# cxg1fcg                    Negative       0.995185
# cnhe0ea                    Negative       0.956195
# cnpg166                    Negative       0.968142
# cvo5mh7                    Negative       0.956407
# cnj9vhu                    Negative       0.998475
# cny256z                    Negative       0.581239
# cnkt8hl                    Negative       0.734431
# cndz93a                    Negative       0.968423
# cnemxpo                    Negative       0.999898
# cnnpopy  Negative Positive Negative       0.981467
# cndtodr                    Negative       0.999931
# cnjpuhe                    Positive       0.897571
# cnc21da                    Negative       0.996929
# cnfygu0                    Negative       0.503621
# cno4vtp                    Negative       0.673559
# cndsgf2                    Positive       0.997087
# cnd33st                    Negative       0.843677
# co73hhe                    Negative       0.893259
# cnip42q                    Negative       0.991882
# cnqnt9w                    Negative       0.998016

# %%
from collections import Counter
drugs = data.drug

# %%
drugs.values
# Out:
# array([u'amitriptyline', u'escitalopram', u'escitalopram', u'fluoxetine',
#        u'escitalopram', u'mirtazapine', u'olanzapine', u'bupropion',
#        u'escitalopram', u'paroxetine', u'sertraline', u'bupropion',
#        u'escitalopram', u'escitalopram', u'venlafaxine', u'escitalopram',
#        u'paroxetine', u'fluoxetine', u'bupropion', u'escitalopram',
#        u'bupropion', u'bupropion', u'fluoxetine', u'escitalopram',
#        u'fluoxetine', u'bupropion', u'escitalopram', u'escitalopram',
#        u'venlafaxine', u'venlafaxine', u'escitalopram', u'sertraline',
#        u'mirtazapine', u'duloxetine', u'escitalopram'], dtype=object)

# %%
c=Counter(drugs.values)

# %%
c.most_common(1)
# Out:
# [(u'escitalopram', 13)]

# %%
data.size
# Out:
# 175

# %%
len(data)
# Out:
# 35

# %%
reload(rec)
sod,sd,bsd,best = rec.recommend('escitalopram')
print sod,sd,bsd,best
# Out:
# 331 5 3 (u'citalopram', 3)

# %%
reload(rec)
sod,sd,bsd,best = rec.recommend('citalopram')
print sod,sd,bsd,best
# Out:
# 131 35 20 (u'bupropion', 6)
